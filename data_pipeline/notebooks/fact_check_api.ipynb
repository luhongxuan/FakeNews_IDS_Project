# %%
import sys
sys.path.append("/app")  # 確保找得到 collectors 模組

from collectors.fact_check import search_claims, parse_claims
import pandas as pd


# ── 試打一個查詢 ──────────────────────────────────────
raw = search_claims("COVID vaccine DNA")
print("原始回傳：")
print(raw)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       1 import sys
#       2 sys.path.append("/app")  # 確保找得到 collectors 模組
# ----> 4 from collectors.fact_check import search_claims, parse_claims
#       5 import pandas as pd
#       8 # ── 試打一個查詢 ──────────────────────────────────────
#
# File /app/collectors/fact_check.py:3
#       1 import os
#       2 import httpx
# ----> 3 from dotenv import load_dotenv
#       5 load_dotenv()
#       7 API_KEY  = os.getenv("GOOGLE_FACT_CHECK_API_KEY")
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
claims = parse_claims(raw)
df = pd.DataFrame(claims)

print(f"找到 {len(df)} 筆查核結果")
df

# %%
print("=== 查核評級分佈 ===")
print(df["rating"].value_counts())

print("\n=== 查核機構 ===")
print(df["reviewer"].value_counts())
